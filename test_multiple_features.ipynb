# %% [markdown]
# <a href="https://colab.research.google.com/github/prodipsarkar03/Learning-Purpose-with-Subin/blob/main/test_multiple_features.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler

# Load dataset
df = pd.read_csv("house_price_data.csv")

# %%
print(df)
# Out:
#        Size_sqft  Bedrooms        Age          Price
# 0    1649.014246  2.171005  23.784943  264543.181412
# 1    1458.520710  2.439819  15.389173  227614.933109
# 2    1694.306561  3.747294  24.348030  280019.801924
# 3    1956.908957  3.610370  26.778189  341819.988798
# 4    1429.753988  2.979098  22.067175  237042.476300
# ..           ...       ...        ...            ...
# 295  1292.127121  2.489984  23.243549  215906.624265
# 296  1769.879963  2.730125  19.164410  282808.284264
# 297  1592.189856  2.021236  20.733568  259723.856154
# 298  1743.858636  2.555707  26.032545  278597.873012
# 299  1688.888653  3.377300  15.915322  306431.450594
#
# [300 rows x 4 columns]

# %%
# Select features and target
X = df[['Size_sqft','Bedrooms','Age','Price']]
y=df['Price']

# %%
print(X)
# Out:
#        Size_sqft  Bedrooms        Age          Price
# 0    1649.014246  2.171005  23.784943  264543.181412
# 1    1458.520710  2.439819  15.389173  227614.933109
# 2    1694.306561  3.747294  24.348030  280019.801924
# 3    1956.908957  3.610370  26.778189  341819.988798
# 4    1429.753988  2.979098  22.067175  237042.476300
# ..           ...       ...        ...            ...
# 295  1292.127121  2.489984  23.243549  215906.624265
# 296  1769.879963  2.730125  19.164410  282808.284264
# 297  1592.189856  2.021236  20.733568  259723.856154
# 298  1743.858636  2.555707  26.032545  278597.873012
# 299  1688.888653  3.377300  15.915322  306431.450594
#
# [300 rows x 4 columns]

# %%
print(y)
# Out:
# 0      264543.181412
# 1      227614.933109
# 2      280019.801924
# 3      341819.988798
# 4      237042.476300
#            ...
# 295    215906.624265
# 296    282808.284264
# 297    259723.856154
# 298    278597.873012
# 299    306431.450594
# Name: Price, Length: 300, dtype: float64

# %%
# Normalize features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
# Out:
# StandardScaler()

# %%
# Add bias column
X_scaled = np.c_[np.ones(X_scaled.shape[0]), X_scaled]

# %%
# Initialize parameters
theta = np.zeros(X_scaled.shape[1])

# %%
# Gradient Descent
alpha = 0.01
iterations = 1000
m = len(y)

for i in range(iterations):
    prediction = X_scaled.dot(theta)
    error = prediction - y
    gradient = (1/m) * X_scaled.T.dot(error)
    theta = theta - alpha * gradient

print("Final parameters (theta):", theta)
# Out:
# Final parameters (theta): [246286.76246226  10817.71514553   2096.40190973   -584.9163642
#   39417.63663876]
